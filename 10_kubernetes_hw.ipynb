# %% [markdown]
# <a href="https://colab.research.google.com/github/alfanugraha/mlzoomcamp-homework/blob/master/10_kubernetes_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Q1. Probability of conversion

# %% [markdown]
# ![Screenshot 2025-12-30 160838.png](data:image/png;base64,...)

# %% [markdown]
# The answer is `0.4999`

# %% [markdown]
# ## Q2. `kind` version

# %% [markdown]
# ![Screenshot 2025-12-30 161131.png](data:image/png;base64,...)

# %% [markdown]
# ## Q3. Smallest deployable compute unit
#
# the smallest deployable and manageable computing unit is a *Pod*
#
# ## Q4. Service type
#
# `ClusterIP` is the current active service
#
# ![Screenshot 2025-12-30 162533.png](data:image/png;base64,...)

# %% [markdown]
# ## Q5. Command to register docker-image to `kind`
#
# `kind load docker-image zoomcamp-model:3.13.10-hw10`

# %% [markdown]
# ## Q6. Port used
#
# ![Screenshot 2025-12-30 163527.png](data:image/png;base64,...)

# %% [markdown]
# ## Q7. App name
#
# `subscription`
#
# ![Screenshot 2025-12-30 164702.png](data:image/png;base64,...)

# %% [markdown]
# ## Q8. The max amount of replicas
#
# The answer is only `1`
#
# ![Screenshot 2025-12-30 165402.png](data:image/png;base64,...)
