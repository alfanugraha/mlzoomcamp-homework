# %% [markdown]
# <a href="https://colab.research.google.com/github/alfanugraha/mlzoomcamp-homework/blob/master/05_deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.getcwd()
# Out:
# 'd:\\My_Course\\Zoomcamp\\mlzoomcamp-homework\\hw05'

# %% [markdown]
# ## Q1. `uv` version

# %%
# !uv --version
# Out:
# uv 0.7.12 (dc3fd4647 2025-06-06)

# %% [markdown]
# ## Q2. First Hash of Scikit-Learn
#
# sha256:b4fc2525eca2c69a59260f583c56a7557c6ccdf8deafdba6e060f94c1c59738e

# %% [markdown]
# ## Q3. Probability of Lead Source
#
# `0.5336072702798061`

# %% [markdown]
# ## Q4. Probability of Lead Source using FastAPI
#
# `{'lead_score': 0.5340417283801275}`

# %% [markdown]
# ## Q5. Docker Image Size
#
# ```
# REPOSITORY                 TAG                    IMAGE ID       CREATED         SIZE
# hw05                       latest                 8376daa2ca70   2 minutes ago   547MB
# agrigorev/zoomcamp-model   2025                   4a9ecc576ae9   12 days ago     121MB
# python                     3.13.5-slim-bookworm   38e57556b635   4 months ago    121MB
# ```
#
# The size of the Docker image is 121MB.

# %% [markdown]
# ## Q5. Probability of Lead Source using Docker
#
# `0.99`

# %% [markdown]
# Docker Commands Used:
#
# ```
# docker build -t hw05 .
#
# docker run -it --rm -p 9696:9696 hw05
#
# uv run python test.py
# ```
